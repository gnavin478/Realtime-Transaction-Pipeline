# %%
pip install confluent-kafka==2.8.2

# %%
import confluent_kafka
print("confluent_kafka installed successfully")

# %%
import sys
import importlib

PROJECT_ROOT = "/Workspace/Repos/gnavin478@gmail.com/Realtime-Transaction-Pipeline"

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

import kafka_producer.producer as producer
importlib.reload(producer)

print("Starting producer...")
producer.main()
print("Producer completed successfully.")
