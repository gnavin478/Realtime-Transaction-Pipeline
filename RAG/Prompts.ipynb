# %%
# %pip install sentence-transformers
dbutils.library.restartPython()

# %%
import sys

PROJECT_ROOT = "/Workspace/Repos/gnavin478/Realtime-Transaction-Pipeline"

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
from RAG.vector_store import build_vector_store

build_vector_store(spark)

# %%
display(
    dbutils.fs.ls(
        "/Volumes/workspace/transaction_data_pipeline/rag/"
    )
)

# %%
display(
    dbutils.fs.ls(
        "/Volumes/workspace/transaction_data_pipeline/rag/tables/transaction_vector_store"
    )
)

# %%
from RAG.rag_pipeline import TransactionRAGPipeline

rag = TransactionRAGPipeline(spark)

print(
    rag.ask(
        "Show high value failed payment transactions"
    )
)

# %%
print(rag.ask("Which city has highest sales?"))
