# %%
import sys
import importlib

sys.path.append("/Workspace/Repos/gnavin478@gmail.com/Realtime-Transaction-Pipeline")

import pyspark_streaming.bronze.bronze_ingest as bronze_ingest
importlib.reload(bronze_ingest)

bronze_ingest.main()

# %%
import sys
import importlib

# Add your repo path
sys.path.append("/Workspace/Repos/gnavin478@gmail.com/Realtime-Transaction-Pipeline")

# Import producer
import kafka_producer.producer as producer

# Reload (important when you change code)
importlib.reload(producer)

# Run producer
producer.main()

# %%
import sys
import importlib

sys.path.append("/Workspace/Repos/gnavin478@gmail.com/Realtime-Transaction-Pipeline")

import pyspark_streaming.silver.silver_transform as silver_transform
importlib.reload(silver_transform)

silver_transform.main()

# %%
import sys
import importlib

sys.path.append("/Workspace/Repos/gnavin478@gmail.com/Realtime-Transaction-Pipeline")

import pyspark_streaming.gold.gold_aggregation as gold_aggregation
importlib.reload(gold_aggregation)

gold_aggregation.main()
